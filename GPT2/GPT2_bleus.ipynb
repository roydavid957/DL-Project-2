# %% [markdown]
# # GPT-2 BLEU Calculator

# %% [markdown]
# The following Jupyter Notebook uses the GPT-2 trained models to calculate BLEU scores for the report.
# In order to run this Notebook, the two models need to be in the same folder as this notebook. These models are generated using
# two GPT-2 scipts. These scripts will take under two hours to run. Furthermore, the correct formatted dataset must also be in the same folder.

# %% [markdown]
# ## Imports

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import re, os, csv, unicodedata, codecs, itertools, requests, random, time, datetime
import pandas as pd
import numpy as np
from io import open
from itertools import compress
import torch
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from nltk.translate.bleu_score import sentence_bleu
from tqdm import tqdm

# %% [markdown]
# ## Load the data

# %%
train_lines = [line for line in open("formatted_movie_QR_lines_train.txt", "r")]
train_pair_lines = train_lines
train_pair_lines = [re.sub(r"([\n])", r"", train_pair_lines[i]) for i, line in enumerate(train_pair_lines)]
train_lines = [re.sub(r"([\t\n])", r"", train_lines[i]) for i, line in enumerate(train_lines)]

test_lines = [line for line in open("formatted_movie_QR_lines_test.txt", "r")]
test_pair_lines = test_lines
test_pair_lines = [re.sub(r"([\n])", r"", test_pair_lines[i]) for i, line in enumerate(test_pair_lines)]
test_lines = [re.sub(r"([\t\n])", r"", test_pair_lines[i]) for i, line in enumerate(test_pair_lines)]

# %%
train_prompts = []
train_refs = []
test_prompts = []
test_refs = []

for i in tqdm(range(100)):
    train_split = train_pair_lines[i].split("\t")
    test_split = test_pair_lines[i].split("\t")

    train_prompts.append(train_split[0])
    train_refs.append(train_split[1])

    test_prompts.append(test_split[0])
    test_refs.append(test_split[1])

# %% [markdown]
# ## Entire Data Model

# %%
# Load the model
model_path = "GPT2_entire_dataset/"

model = GPT2LMHeadModel.from_pretrained(output_dir)
tokenizer = GPT2Tokenizer.from_pretrained(output_dir)

# %%
# Train BLEUS
train_bleus = []
for i in tqdm(range(100)):
    prompt = "<|startoftext|>" + train_prompts[i]
    prompt = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

    generated = model.generate(
        prompt,
        do_sample = True,
        top_k = 50,
        max_length = 300,
        top_p = 0.95,
        num_return_sequences = 1
    )

    candidate = tokenizer.decode(generated[0], skip_special_tokens = True)
    bleu = sentence_bleu(train_refs, candidate)
    train_bleus.append(bleu)

# Test BLEUS
test_bleus = []
for i in tqdm(range(100)):
    prompt = "<|startoftext|>" + test_prompts[i]
    prompt = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

    generated = model.generate(
        prompt,
        do_sample = True,
        top_k = 50,
        max_length = 300,
        top_p = 0.95,
        num_return_sequences = 1
    )

    candidate = tokenizer.decode(generated[0], skip_special_tokens = True)
    bleu = sentence_bleu(test_refs, candidate)
    test_bleus.append(bleu)

# Average the scores
entire_train_bleus = np.mean(train_bleus)
entire_test_bleus = np.mean(test_bleus)
# Out:
# 2%|███▏      | 32/100 [00:10<00:19,  3.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  33%|███▎      | 33/100 [00:10<00:20,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  34%|███▍      | 34/100 [00:10<00:21,  3.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  35%|███▌      | 35/100 [00:11<00:18,  3.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  36%|███▌      | 36/100 [00:11<00:21,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  37%|███▋      | 37/100 [00:11<00:20,  3.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38%|███▊      | 38/100 [00:12<00:19,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  39%|███▉      | 39/100 [00:12<00:18,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40%|████      | 40/100 [00:12<00:18,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  41%|████      | 41/100 [00:13<00:26,  2.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42%|████▏     | 42/100 [00:13<00:22,  2.61it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  43%|████▎     | 43/100 [00:14<00:22,  2.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  44%|████▍     | 44/100 [00:14<00:23,  2.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  45%|████▌     | 45/100 [00:15<00:22,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46%|████▌     | 46/100 [00:15<00:19,  2.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  47%|████▋     | 47/100 [00:15<00:18,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  48%|████▊     | 48/100 [00:15<00:14,  3.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  49%|████▉     | 49/100 [00:15<00:12,  3.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50%|█████     | 50/100 [00:16<00:16,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  51%|█████     | 51/100 [00:16<00:16,  3.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  52%|█████▏    | 52/100 [00:17<00:17,  2.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  53%|█████▎    | 53/100 [00:17<00:19,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54%|█████▍    | 54/100 [00:18<00:18,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  55%|█████▌    | 55/100 [00:18<00:16,  2.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  56%|█████▌    | 56/100 [00:18<00:18,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  57%|█████▋    | 57/100 [00:19<00:15,  2.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58%|█████▊    | 58/100 [00:19<00:16,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  59%|█████▉    | 59/100 [00:19<00:14,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60%|██████    | 60/100 [00:20<00:17,  2.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  61%|██████    | 61/100 [00:20<00:14,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  62%|██████▏   | 62/100 [00:21<00:14,  2.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  63%|██████▎   | 63/100 [00:21<00:11,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  64%|██████▍   | 64/100 [00:21<00:10,  3.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  65%|██████▌   | 65/100 [00:22<00:12,  2.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  66%|██████▌   | 66/100 [00:22<00:11,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67%|██████▋   | 67/100 [00:22<00:09,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  68%|██████▊   | 68/100 [00:22<00:08,  3.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  69%|██████▉   | 69/100 [00:22<00:07,  4.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  70%|███████   | 70/100 [00:23<00:07,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71%|███████   | 71/100 [00:23<00:07,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  72%|███████▏  | 72/100 [00:23<00:06,  4.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  73%|███████▎  | 73/100 [00:23<00:05,  4.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  74%|███████▍  | 74/100 [00:24<00:06,  3.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75%|███████▌  | 75/100 [00:24<00:06,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  76%|███████▌  | 76/100 [00:24<00:06,  3.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  77%|███████▋  | 77/100 [00:25<00:06,  3.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  78%|███████▊  | 78/100 [00:25<00:09,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79%|███████▉  | 79/100 [00:26<00:08,  2.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  80%|████████  | 80/100 [00:26<00:07,  2.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  81%|████████  | 81/100 [00:27<00:07,  2.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  82%|████████▏ | 82/100 [00:27<00:06,  2.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83%|████████▎ | 83/100 [00:27<00:05,  3.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  84%|████████▍ | 84/100 [00:27<00:05,  3.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  85%|████████▌ | 85/100 [00:28<00:04,  3.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  86%|████████▌ | 86/100 [00:28<00:05,  2.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  87%|████████▋ | 87/100 [00:28<00:04,  2.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88%|████████▊ | 88/100 [00:29<00:03,  3.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  89%|████████▉ | 89/100 [00:29<00:03,  2.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90%|█████████ | 90/100 [00:29<00:03,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  91%|█████████ | 91/100 [00:30<00:02,  3.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92%|█████████▏| 92/100 [00:30<00:02,  3.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  93%|█████████▎| 93/100 [00:30<00:02,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  94%|█████████▍| 94/100 [00:31<00:01,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  95%|█████████▌| 95/100 [00:31<00:01,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96%|█████████▌| 96/100 [00:31<00:01,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  97%|█████████▋| 97/100 [00:31<00:00,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  98%|█████████▊| 98/100 [00:32<00:00,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 100/100 [00:32<00:00,  3.06it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 1/100 [00:00<00:28,  3.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 2/100 [00:00<00:30,  3.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 3/100 [00:01<00:34,  2.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   4%|▍         | 4/100 [00:01<00:37,  2.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   5%|▌         | 5/100 [00:02<00:39,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   6%|▌         | 6/100 [00:02<00:32,  2.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   7%|▋         | 7/100 [00:02<00:30,  3.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   8%|▊         | 8/100 [00:02<00:25,  3.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   9%|▉         | 9/100 [00:03<00:27,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  10%|█         | 10/100 [00:03<00:28,  3.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  11%|█         | 11/100 [00:03<00:27,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  12%|█▏        | 12/100 [00:04<00:29,  3.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  13%|█▎        | 13/100 [00:04<00:28,  3.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  14%|█▍        | 14/100 [00:04<00:28,  3.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  15%|█▌        | 15/100 [00:05<00:34,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  16%|█▌        | 16/100 [00:05<00:28,  2.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  17%|█▋        | 17/100 [00:05<00:26,  3.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  18%|█▊        | 18/100 [00:06<00:27,  2.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  19%|█▉        | 19/100 [00:06<00:23,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  20%|██        | 20/100 [00:06<00:23,  3.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  21%|██        | 21/100 [00:06<00:24,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  22%|██▏       | 22/100 [00:07<00:21,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  23%|██▎       | 23/100 [00:07<00:24,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  24%|██▍       | 24/100 [00:07<00:26,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  25%|██▌       | 25/100 [00:08<00:24,  3.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  26%|██▌       | 26/100 [00:08<00:20,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  27%|██▋       | 27/100 [00:08<00:22,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  28%|██▊       | 28/100 [00:09<00:19,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  29%|██▉       | 29/100 [00:09<00:19,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  30%|███       | 30/100 [00:09<00:21,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  31%|███       | 31/100 [00:10<00:23,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  32%|███▏      | 32/100 [00:10<00:21,  3.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  34%|███▍      | 34/100 [00:10<00:19,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  35%|███▌      | 35/100 [00:11<00:17,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  37%|███▋      | 37/100 [00:11<00:15,  4.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38%|███▊      | 38/100 [00:11<00:18,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  39%|███▉      | 39/100 [00:11<00:15,  4.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40%|████      | 40/100 [00:12<00:12,  4.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  41%|████      | 41/100 [00:12<00:15,  3.79it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42%|████▏     | 42/100 [00:12<00:15,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  43%|████▎     | 43/100 [00:12<00:14,  3.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  44%|████▍     | 44/100 [00:13<00:16,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  45%|████▌     | 45/100 [00:13<00:19,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46%|████▌     | 46/100 [00:14<00:22,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  47%|████▋     | 47/100 [00:14<00:20,  2.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  48%|████▊     | 48/100 [00:15<00:19,  2.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  49%|████▉     | 49/100 [00:15<00:19,  2.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50%|█████     | 50/100 [00:15<00:17,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  51%|█████     | 51/100 [00:16<00:17,  2.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  52%|█████▏    | 52/100 [00:16<00:17,  2.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  53%|█████▎    | 53/100 [00:16<00:15,  3.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54%|█████▍    | 54/100 [00:17<00:17,  2.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  55%|█████▌    | 55/100 [00:17<00:16,  2.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  56%|█████▌    | 56/100 [00:17<00:14,  3.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  57%|█████▋    | 57/100 [00:18<00:12,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58%|█████▊    | 58/100 [00:18<00:12,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  59%|█████▉    | 59/100 [00:18<00:11,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60%|██████    | 60/100 [00:19<00:13,  3.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  61%|██████    | 61/100 [00:19<00:13,  2.97it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  62%|██████▏   | 62/100 [00:19<00:11,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  63%|██████▎   | 63/100 [00:19<00:11,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  64%|██████▍   | 64/100 [00:20<00:10,  3.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  65%|██████▌   | 65/100 [00:20<00:13,  2.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  66%|██████▌   | 66/100 [00:20<00:10,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67%|██████▋   | 67/100 [00:21<00:09,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  68%|██████▊   | 68/100 [00:21<00:09,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  69%|██████▉   | 69/100 [00:21<00:10,  3.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71%|███████   | 71/100 [00:22<00:09,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  72%|███████▏  | 72/100 [00:22<00:09,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  73%|███████▎  | 73/100 [00:23<00:10,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  74%|███████▍  | 74/100 [00:23<00:09,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75%|███████▌  | 75/100 [00:23<00:07,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  76%|███████▌  | 76/100 [00:24<00:07,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  77%|███████▋  | 77/100 [00:24<00:06,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  78%|███████▊  | 78/100 [00:24<00:06,  3.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79%|███████▉  | 79/100 [00:25<00:07,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  80%|████████  | 80/100 [00:25<00:06,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  81%|████████  | 81/100 [00:25<00:06,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  82%|████████▏ | 82/100 [00:26<00:05,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83%|████████▎ | 83/100 [00:26<00:06,  2.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  84%|████████▍ | 84/100 [00:26<00:05,  2.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  85%|████████▌ | 85/100 [00:27<00:04,  3.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  86%|████████▌ | 86/100 [00:27<00:04,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88%|████████▊ | 88/100 [00:27<00:03,  3.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  89%|████████▉ | 89/100 [00:28<00:03,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90%|█████████ | 90/100 [00:28<00:03,  3.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  91%|█████████ | 91/100 [00:29<00:03,  2.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92%|█████████▏| 92/100 [00:29<00:02,  3.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  93%|█████████▎| 93/100 [00:29<00:02,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  94%|█████████▍| 94/100 [00:29<00:02,  2.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  95%|█████████▌| 95/100 [00:30<00:01,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96%|█████████▌| 96/100 [00:30<00:01,  2.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  97%|█████████▋| 97/100 [00:30<00:00,  3.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  98%|█████████▊| 98/100 [00:31<00:00,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99%|█████████▉| 99/100 [00:31<00:00,  3.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 100/100 [00:31<00:00,  3.13it/s]

# %% [markdown]
# ## Formatted Data Model

# %%
# Load the model
model_path = "GPT2_dialogue_model/"

model = GPT2LMHeadModel.from_pretrained(output_dir)
tokenizer = GPT2Tokenizer.from_pretrained(output_dir)

# %%
# Train BLEUS
train_bleus = []
for i in tqdm(range(100)):
    prompt = "<|startoftext|>" + train_prompts[i]
    prompt = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

    generated = model.generate(
        prompt,
        do_sample = True,
        top_k = 50,
        max_length = 300,
        top_p = 0.95,
        num_return_sequences = 1
    )

    candidate = tokenizer.decode(generated[0], skip_special_tokens = True)
    bleu = sentence_bleu(train_refs, candidate)
    train_bleus.append(bleu)

# Test BLEUS
test_bleus = []
for i in tqdm(range(100)):
    prompt = "<|startoftext|>" + test_prompts[i]
    prompt = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)

    generated = model.generate(
        prompt,
        do_sample = True,
        top_k = 50,
        max_length = 300,
        top_p = 0.95,
        num_return_sequences = 1
    )

    candidate = tokenizer.decode(generated[0], skip_special_tokens = True)
    bleu = sentence_bleu(test_refs, candidate)
    test_bleus.append(bleu)

# Average the scores
formatted_train_bleus = np.mean(train_bleus)
formatted_test_bleus = np.mean(test_bleus)
# Out:
# :11<00:19,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  32%|███▏      | 32/100 [00:11<00:21,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  33%|███▎      | 33/100 [00:11<00:20,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  34%|███▍      | 34/100 [00:11<00:18,  3.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  35%|███▌      | 35/100 [00:12<00:17,  3.79it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  36%|███▌      | 36/100 [00:12<00:14,  4.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  37%|███▋      | 37/100 [00:12<00:14,  4.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38%|███▊      | 38/100 [00:12<00:13,  4.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  39%|███▉      | 39/100 [00:13<00:17,  3.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40%|████      | 40/100 [00:13<00:19,  3.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  41%|████      | 41/100 [00:13<00:18,  3.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42%|████▏     | 42/100 [00:14<00:18,  3.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  43%|████▎     | 43/100 [00:14<00:17,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  44%|████▍     | 44/100 [00:14<00:15,  3.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  45%|████▌     | 45/100 [00:15<00:17,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46%|████▌     | 46/100 [00:15<00:15,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  47%|████▋     | 47/100 [00:15<00:15,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  48%|████▊     | 48/100 [00:16<00:17,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  49%|████▉     | 49/100 [00:16<00:16,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50%|█████     | 50/100 [00:16<00:20,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  51%|█████     | 51/100 [00:17<00:16,  2.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  52%|█████▏    | 52/100 [00:17<00:19,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  53%|█████▎    | 53/100 [00:17<00:16,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54%|█████▍    | 54/100 [00:18<00:15,  3.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  55%|█████▌    | 55/100 [00:18<00:14,  3.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  56%|█████▌    | 56/100 [00:18<00:13,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  57%|█████▋    | 57/100 [00:19<00:13,  3.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58%|█████▊    | 58/100 [00:19<00:11,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  59%|█████▉    | 59/100 [00:19<00:12,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60%|██████    | 60/100 [00:19<00:10,  3.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  61%|██████    | 61/100 [00:20<00:10,  3.61it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  62%|██████▏   | 62/100 [00:20<00:13,  2.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  64%|██████▍   | 64/100 [00:21<00:10,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  65%|██████▌   | 65/100 [00:21<00:11,  3.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  66%|██████▌   | 66/100 [00:21<00:12,  2.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67%|██████▋   | 67/100 [00:22<00:11,  2.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  68%|██████▊   | 68/100 [00:22<00:09,  3.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  69%|██████▉   | 69/100 [00:22<00:08,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  70%|███████   | 70/100 [00:22<00:08,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71%|███████   | 71/100 [00:23<00:10,  2.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  72%|███████▏  | 72/100 [00:23<00:09,  2.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  73%|███████▎  | 73/100 [00:24<00:09,  2.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  74%|███████▍  | 74/100 [00:24<00:09,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75%|███████▌  | 75/100 [00:24<00:07,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  76%|███████▌  | 76/100 [00:24<00:07,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  77%|███████▋  | 77/100 [00:25<00:07,  2.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  78%|███████▊  | 78/100 [00:26<00:09,  2.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79%|███████▉  | 79/100 [00:26<00:09,  2.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  80%|████████  | 80/100 [00:26<00:08,  2.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  81%|████████  | 81/100 [00:27<00:07,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  82%|████████▏ | 82/100 [00:27<00:05,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83%|████████▎ | 83/100 [00:27<00:05,  3.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  84%|████████▍ | 84/100 [00:28<00:05,  3.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  85%|████████▌ | 85/100 [00:28<00:04,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  86%|████████▌ | 86/100 [00:28<00:04,  3.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  87%|████████▋ | 87/100 [00:29<00:05,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88%|████████▊ | 88/100 [00:29<00:04,  2.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  89%|████████▉ | 89/100 [00:29<00:03,  2.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90%|█████████ | 90/100 [00:30<00:03,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  91%|█████████ | 91/100 [00:30<00:03,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92%|█████████▏| 92/100 [00:30<00:02,  2.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  93%|█████████▎| 93/100 [00:31<00:02,  3.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  94%|█████████▍| 94/100 [00:31<00:01,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  95%|█████████▌| 95/100 [00:31<00:01,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96%|█████████▌| 96/100 [00:32<00:01,  3.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  97%|█████████▋| 97/100 [00:32<00:01,  2.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  98%|█████████▊| 98/100 [00:32<00:00,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99%|█████████▉| 99/100 [00:33<00:00,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 100/100 [00:33<00:00,  3.00it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   1%|          | 1/100 [00:00<00:42,  2.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   2%|▏         | 2/100 [00:01<00:46,  2.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   3%|▎         | 3/100 [00:01<00:37,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   4%|▍         | 4/100 [00:01<00:29,  3.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   5%|▌         | 5/100 [00:01<00:32,  2.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   6%|▌         | 6/100 [00:02<00:32,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   8%|▊         | 8/100 [00:02<00:29,  3.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   9%|▉         | 9/100 [00:02<00:27,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  10%|█         | 10/100 [00:03<00:24,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  11%|█         | 11/100 [00:03<00:24,  3.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  12%|█▏        | 12/100 [00:03<00:25,  3.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  13%|█▎        | 13/100 [00:03<00:22,  3.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  14%|█▍        | 14/100 [00:04<00:29,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  15%|█▌        | 15/100 [00:04<00:30,  2.79it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  16%|█▌        | 16/100 [00:05<00:32,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  17%|█▋        | 17/100 [00:05<00:26,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  18%|█▊        | 18/100 [00:05<00:23,  3.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  19%|█▉        | 19/100 [00:05<00:21,  3.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  20%|██        | 20/100 [00:06<00:21,  3.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  21%|██        | 21/100 [00:06<00:21,  3.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  22%|██▏       | 22/100 [00:06<00:21,  3.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  23%|██▎       | 23/100 [00:06<00:20,  3.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  24%|██▍       | 24/100 [00:07<00:23,  3.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  25%|██▌       | 25/100 [00:07<00:21,  3.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  26%|██▌       | 26/100 [00:07<00:19,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  27%|██▋       | 27/100 [00:08<00:18,  3.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  28%|██▊       | 28/100 [00:08<00:19,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  29%|██▉       | 29/100 [00:08<00:19,  3.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  30%|███       | 30/100 [00:08<00:19,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  31%|███       | 31/100 [00:09<00:26,  2.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  32%|███▏      | 32/100 [00:09<00:26,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  33%|███▎      | 33/100 [00:10<00:22,  3.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  34%|███▍      | 34/100 [00:10<00:20,  3.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  35%|███▌      | 35/100 [00:10<00:18,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  37%|███▋      | 37/100 [00:11<00:16,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38%|███▊      | 38/100 [00:11<00:18,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  39%|███▉      | 39/100 [00:11<00:18,  3.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  40%|████      | 40/100 [00:12<00:19,  3.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  41%|████      | 41/100 [00:12<00:17,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42%|████▏     | 42/100 [00:12<00:17,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  43%|████▎     | 43/100 [00:12<00:16,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  44%|████▍     | 44/100 [00:13<00:19,  2.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  45%|████▌     | 45/100 [00:13<00:19,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46%|████▌     | 46/100 [00:13<00:16,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  47%|████▋     | 47/100 [00:14<00:14,  3.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  48%|████▊     | 48/100 [00:14<00:12,  4.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  49%|████▉     | 49/100 [00:14<00:11,  4.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50%|█████     | 50/100 [00:14<00:11,  4.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  51%|█████     | 51/100 [00:15<00:13,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  52%|█████▏    | 52/100 [00:15<00:14,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  53%|█████▎    | 53/100 [00:15<00:16,  2.80it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54%|█████▍    | 54/100 [00:16<00:16,  2.81it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  55%|█████▌    | 55/100 [00:16<00:14,  3.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  56%|█████▌    | 56/100 [00:17<00:15,  2.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  57%|█████▋    | 57/100 [00:17<00:16,  2.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58%|█████▊    | 58/100 [00:17<00:15,  2.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  59%|█████▉    | 59/100 [00:18<00:13,  3.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  60%|██████    | 60/100 [00:18<00:12,  3.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  61%|██████    | 61/100 [00:18<00:11,  3.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  63%|██████▎   | 63/100 [00:18<00:09,  3.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  64%|██████▍   | 64/100 [00:19<00:09,  3.61it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  65%|██████▌   | 65/100 [00:19<00:08,  4.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  66%|██████▌   | 66/100 [00:19<00:08,  3.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67%|██████▋   | 67/100 [00:19<00:07,  4.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  68%|██████▊   | 68/100 [00:20<00:08,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  69%|██████▉   | 69/100 [00:20<00:08,  3.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  70%|███████   | 70/100 [00:20<00:09,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71%|███████   | 71/100 [00:21<00:08,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  72%|███████▏  | 72/100 [00:21<00:07,  3.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  73%|███████▎  | 73/100 [00:21<00:08,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75%|███████▌  | 75/100 [00:22<00:06,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  76%|███████▌  | 76/100 [00:22<00:07,  3.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  77%|███████▋  | 77/100 [00:22<00:07,  3.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  78%|███████▊  | 78/100 [00:23<00:07,  3.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79%|███████▉  | 79/100 [00:23<00:06,  3.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  81%|████████  | 81/100 [00:23<00:05,  3.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  82%|████████▏ | 82/100 [00:24<00:05,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83%|████████▎ | 83/100 [00:24<00:05,  3.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  84%|████████▍ | 84/100 [00:24<00:04,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  85%|████████▌ | 85/100 [00:25<00:03,  3.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  86%|████████▌ | 86/100 [00:25<00:04,  3.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88%|████████▊ | 88/100 [00:25<00:03,  3.86it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  89%|████████▉ | 89/100 [00:26<00:03,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  90%|█████████ | 90/100 [00:26<00:02,  3.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  91%|█████████ | 91/100 [00:26<00:02,  3.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92%|█████████▏| 92/100 [00:26<00:02,  3.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  93%|█████████▎| 93/100 [00:27<00:01,  3.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  94%|█████████▍| 94/100 [00:27<00:01,  4.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  95%|█████████▌| 95/100 [00:27<00:01,  2.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96%|█████████▌| 96/100 [00:28<00:01,  3.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  97%|█████████▋| 97/100 [00:28<00:00,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  98%|█████████▊| 98/100 [00:28<00:00,  3.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  99%|█████████▉| 99/100 [00:29<00:00,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 100/100 [00:29<00:00,  3.41it/s]

# %%
print(f"Entire: train - {entire_train_bleus}; test - {entire_test_bleus}")
print(f"Formatted: train - {formatted_train_bleus}; test - {formatted_test_bleus}")
# Out:
# Entire: train - 0.6493910897921685; test - 0.6458795430496364
# Formatted: train - 0.6560220578207043; test - 0.6513421845508242
